# %% [markdown]
# # Edge-IIoTset: Silver ve Gold Katman Sunumu
# Bu notebook, projemizin **Adım 5** (Veri Kalitesi, Temizleme ve Feature Engineering) aşamasının sonuçlarını hocaya sunmak için hazırlanmıştır.

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("Presentation") \
    .config("spark.jars.packages", "io.delta:delta-core_2.12:2.4.0") \
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog") \
    .getOrCreate()

# %% [markdown]
# ## 1. Silver Layer (Temizlenmiş Veri)
# Bu katmanda ham verideki gereksiz kolonlar (ARP, ICMP) atılmış, Null/Inf değerler doldurulmuş ve duplikat satırlar temizlenmiştir.

# %%
silver_df = spark.read.format("delta").load("/opt/bitnami/spark/delta-storage/silver/network_traffic")
print(f"Silver Layer Satır Sayısı: {silver_df.count():,}")
print(f"Silver Layer Kolon Sayısı: {len(silver_df.columns)}")

# Noktalı kolon isimleri nedeniyle PySpark hata vermesin diye etrafına ` (backtick) ekliyoruz
silver_df.select("`frame.time`", "`ip.src_host`", "`ip.dst_host`", "Attack_label", "Attack_type").limit(5).toPandas()
# Out:
# Silver Layer Satır Sayısı: 156,986
# Silver Layer Kolon Sayısı: 55
#   frame.time ip.src_host ip.dst_host  Attack_label Attack_type
# 0        0.0           0         0.0             1        MITM
# 1        0.0           0         0.0             1        MITM
# 2        0.0           0         0.0             1        MITM
# 3        0.0           0         0.0             1        MITM
# 4        0.0           0         0.0             1        MITM

# %% [markdown]
# ## 2. Gold Layer (Feature Engineering - ML'e Hazır)
# Bu katmanda Silver verisi üzerine siber saldırı tespitine yönelik **5 yeni makine öğrenmesi özelliği (feature)** eklenmiştir.
#
# ---
#
# ### Neden Bu 5 Feature Seçildi?
#
# IoT ağ saldırıları genellikle **trafik hacmi**, **bağlantı davranışı** ve **zamanlama düzeni** açısından normal trafikten ayrılır. Aşağıdaki 5 feature, bu üç boyutu kapsayacak şekilde tasarlanmıştır:
#
# | # | Feature | Formül | İş Mantığı | Hedef Saldırı Tipleri |
# |---|---------|--------|------------|----------------------|
# | 1 | **traffic_asymmetry_ratio** | `tcp_ack / (tcp_seq + 1)` | Normal TCP trafiğinde ACK ve SEQ sayıları simetrik ilerler. DDoS saldırılarında saldırgan çok sayıda SYN gönderir ama ACK dönemini tamamlamaz (SYN flood), bu yüzden oran bozulur. | DDoS TCP/UDP/ICMP, SYN Flood |
# | 2 | **pkt_size_cv** | `\|tcp_len - tcp_payload\| / (tcp_len + 1)` | Normal trafik tutarlı paket boyutlarına sahipken, port tarama ve zafiyet tarama saldırıları farklı boyutlarda paketler gönderir. Bu varyasyon katsayısı (CV) bu farkı yakalar. | Port Scanning, Vulnerability Scanner, Fingerprinting |
# | 3 | **flow_intensity** | `tcp_len * tcp_flags` | Paket boyutunu ve bayrak sayısını tek bir metrikte birleştirir. Volumetrik saldırılarda (flood) hem boyut hem flag anormal değerler alır; bu çarpım bu anomaliyi güçlendirir. | DDoS UDP/ICMP/HTTP Flood |
# | 4 | **iat_regularity** | `udp_time_delta / (frame_time + 1)` | Botnet ve otomatize tarama araçları paketleri çok düzenli aralıklarla gönderir. İnsan kaynaklı trafik ise düzensizdir. Bu oran düzenli gönderim yapan bot'ları tespit eder. | Botnet, Automated Scanning, Password Brute Force |
# | 5 | **conn_efficiency** | `tcp_connection_syn / (tcp_connection_fin + tcp_connection_rst + 1)` | Normal TCP bağlantısında SYN→FIN/RST oranı ~1'dir. Port tarama ve fingerprinting saldırıları çok sayıda SYN gönderir ama bağlantıyı tamamlamaz, oran çok yükselir. | Port Scanning, OS Fingerprinting, SYN Flood |

# %%
gold_df = spark.read.format("delta").load("/opt/bitnami/spark/delta-storage/gold/ml_ready")
print(f"Gold Layer Satır Sayısı: {gold_df.count():,}")
print(f"Gold Layer Kolon Sayısı: {len(gold_df.columns)}")
# Out:
# Gold Layer Satır Sayısı: 156,986
# Gold Layer Kolon Sayısı: 60

# %% [markdown]
# ### Yeni Üretilen 5 Feature'ın Görünümü
# DDoS, Port Scanning ve Botnet tespiti için eklenen istatistiksel özelliklerin normal ve saldırı trafiğindeki karşılıkları:

# %%
features = ["traffic_asymmetry_ratio", "pkt_size_cv", "flow_intensity", "iat_regularity", "conn_efficiency"]

# Sadece saldırı (Attack_label == 1) trafiğine ait yeni özelliklerin ilk 10 kaydı
gold_df.select(["Attack_type"] + features).filter("Attack_label == 1").limit(10).toPandas()
# Out:
#   Attack_type  traffic_asymmetry_ratio  pkt_size_cv  flow_intensity  \
# 0        MITM                      0.0     0.999066             0.0
# 1        MITM                      0.0     0.998879             0.0
# 2        MITM                      0.0     0.999756             0.0
# 3        MITM                      0.0     0.998879             0.0
# 4        MITM                      0.0     0.998879             0.0
# 5        MITM                      0.0     0.998879             0.0
# 6        MITM                      0.0     0.998879             0.0
# 7        MITM                      0.0     0.999066             0.0
# 8        MITM                      0.0     0.998879             0.0
# 9        MITM                      0.0     0.999066             0.0
#
#    iat_regularity  conn_efficiency
# 0           255.0              0.0
# 1            12.0              0.0
# 2           255.0              0.0
# 3           255.0              0.0
# 4           255.0              0.0
# ...

# %%
# Feature'ların İstatistiksel Özeti (min, max, mean, stddev)
features = ["traffic_asymmetry_ratio", "pkt_size_cv", "flow_intensity", "iat_regularity", "conn_efficiency"]
gold_df.select(features).describe().toPandas()

# %%
# Feature Dağılımları: Normal vs Saldırı Karşılaştırması
import matplotlib.pyplot as plt

features = ["traffic_asymmetry_ratio", "pkt_size_cv", "flow_intensity", "iat_regularity", "conn_efficiency"]
pdf = gold_df.select(features + ["Attack_label"]).toPandas()

fig, axes = plt.subplots(1, 5, figsize=(22, 4))
for i, feat in enumerate(features):
    normal = pdf[pdf["Attack_label"] == 0][feat]
    attack = pdf[pdf["Attack_label"] == 1][feat]
    axes[i].hist(normal, bins=30, alpha=0.6, label="Normal", color="steelblue", density=True)
    axes[i].hist(attack, bins=30, alpha=0.6, label="Saldırı", color="salmon", density=True)
    axes[i].set_title(feat, fontsize=9)
    axes[i].legend(fontsize=7)
    axes[i].tick_params(labelsize=7)

fig.suptitle("5 Feature Dağılımı: Normal vs Saldırı Trafiği", fontsize=13)
plt.tight_layout()
plt.show()
